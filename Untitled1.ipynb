# %%
# importing required libraries 
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd

# %%
from PIL import Image
import os

# def load_images_from_folder(folder):
images = []
folder = 'C:/Users/aarti_r5y998e/Desktop/DAVIS_VideoObject-Segmentation-from-One-Frame-Annotation-master/Video-Object-Segmentation-from-One-Frame-Annotation-master/DAVIS'
trainfile = open('C:/Users/aarti_r5y998e/Desktop/DAVIS_VideoObject-Segmentation-from-One-Frame-Annotation-master/Video-Object-Segmentation-from-One-Frame-Annotation-master/DAVIS/ImageSets/480p/train.txt', 'r')
for line in trainfile:
    for imgpath in line.split():
        img = Image.open(folder+imgpath)
        images.append(img)
    
#     for filename in os.listdir(folder):
#         img = Image.open(os.path.join(folder,filename))
#         images.append(img)
# 	return images
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-5e8f0ef7096a> in <module>
#       8 for line in trainfile:
#       9     for imgpath in line.split():
# ---> 10         img = Image.open(folder+imgpath)
#      11         images.append(img)
#      12
#
# ~\anaconda\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2632
#    2633     if filename:
# -> 2634         fp = builtins.open(filename, "rb")
#    2635         exclusive_fp = True
#    2636
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/aarti_r5y998e/Desktop/DAVIS_VideoObject-Segmentation-from-One-Frame-Annotation-master/Video-Object-Segmentation-from-One-Frame-Annotation-master/DAVIS/JPEGImages/480p/bmx-bumps/00000.jpg'
